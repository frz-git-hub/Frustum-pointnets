# %% [markdown]
# Version Ckeck

# %%
# %tensorflow_version 1.x

# %%
import tensorflow
print(tensorflow.__version__)

# %%
# !nvidia-smi

# %%
# !nvcc --version

# %%
# !python --version

# %%
# !kaggle --version

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Project Preparate

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
rm -r sample_data/

# %%
# cp -R "/content/drive/MyDrive/Colab Notebooks/proposal_project/Frustum Pointnet/frustum-pointnets" ./
# !cp -R /content/drive/MyDrive/Colab/Frustum-pointnets/frustum-pointnets ./

# %% [markdown]
# ssample data

# %%
# %cd frustum-pointnets/dataset/KITTI/object/

# %%
# !unzip sample_data.zip
# !mv sample_data/training ./
# !rm -r sample_data/

# %% [markdown]
# kitti_eval

# %%
# !rm -r training/label_2

# %%
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip
# !unzip data_object_label_2.zip
# !rm data_object_label_2.zip

# %%
# %cd /content/frustum-pointnets/train/kitti_eval
# !bash ./compile.sh

# %% [markdown]
# Pickle files (Frustum Data Crop)

# %%
# %cd /content/frustum-pointnets/kitti/
# !kaggle datasets download -d farazhajatdoost/preparation-frustum-data --unzip
# Out:
# /content/frustum-pointnets/kitti
# Downloading preparation-frustum-data.zip to /content/frustum-pointnets/kitti
#  99% 553M/556M [00:06<00:00, 80.6MB/s]
# 100% 556M/556M [00:06<00:00, 93.6MB/s]

# %% [markdown]
# Train

# %%
# %cd /content/frustum-pointnets/

# %%
# !CUDA_VISIBLE_DEVICES=0 sh scripts/command_train_v1.sh

# %% [markdown]
# Test

# %%
# !CUDA_VISIBLE_DEVICES=0 sh scripts/command_test_v1.sh

# %% [markdown]
# Visulization

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir /content/frustum-pointnets/train/log_v1

# %%
# !python kitti/kitti_object.py

# %% [markdown]
# BackUp

# %%
# !rm -r /content/drive/MyDrive/Frustum-pointnets/frustum-pointnets/train
# !cp -R /content/frustum-pointnets/train  /content/drive/MyDrive/Frustum-pointnets/frustum-pointnets/train
