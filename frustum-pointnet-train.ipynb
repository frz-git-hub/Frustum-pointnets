# %% [markdown]
# Version Ckeck

# %%
# %tensorflow_version 1.x

# %%
import tensorflow
print(tensorflow.__version__)

# %%
# !nvidia-smi

# %%
# !nvcc --version

# %%
# !python --version

# %%
# !kaggle --version

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Project Preparate

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
rm -r sample_data/

# %%
cp -R "/content/drive/MyDrive/Colab Notebooks/proposal_project/Frustum Pointnet/frustum-pointnets" ./

# %% [markdown]
# kaggle pickle

# %%
# %cd frustum-pointnets/dataset/KITTI/object/
# Out:
# /content/frustum-pointnets/dataset/KITTI/object

# %%
# !unzip sample_data.zip "sample_data/training/*"
# !mv sample_data/training ./
# !rm -r sample_data/

# %%
# !rm -r training/label_2

# %%
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip
# !unzip data_object_label_2.zip
# !rm data_object_label_2.zip

# %%
# %cd /content/frustum-pointnets/train/kitti_eval
# !bash ./compile.sh

# %%
# %cd /content/frustum-pointnets/kitti/
# !kaggle datasets download -d farazhajatdoost/preparation-frustum-data --unzip

# %% [markdown]
# Train

# %%
# %cd /content/frustum-pointnets/

# %%
# !CUDA_VISIBLE_DEVICES=0 sh scripts/command_train_v1.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# mean loss: 4.593105
# segmentation accuracy: 0.925177
# box IoU (ground/3D): 0.740680 / 0.681361
# box estimation accuracy (IoU=0.7): 0.634375
#  -- 1630 / 2294 --
# mean loss: 3.288868
# segmentation accuracy: 0.915979
# box IoU (ground/3D): 0.728705 / 0.673324
# box estimation accuracy (IoU=0.7): 0.578125
#  -- 1640 / 2294 --
# mean loss: 3.191386
# segmentation accuracy: 0.929895
# box IoU (ground/3D): 0.733421 / 0.676630
# box estimation accuracy (IoU=0.7): 0.571875
#  -- 1650 / 2294 --
# mean loss: 3.598201
# segmentation accuracy: 0.935165
# box IoU (ground/3D): 0.717359 / 0.659820
# box estimation accuracy (IoU=0.7): 0.540625
#  -- 1660 / 2294 --
# mean loss: 2.708765
# segmentation accuracy: 0.927362
# box IoU (ground/3D): 0.739743 / 0.686686
# box estimation accuracy (IoU=0.7): 0.625000
#  -- 1670 / 2294 --
# mean loss: 2.539974
# segmentation accuracy: 0.918744
# box IoU (ground/3D): 0.751481 / 0.696478
# ...

# %% [markdown]
# Test

# %%
# !CUDA_VISIBLE_DEVICES=0 sh scripts/command_test_v1.sh
# Out:
# 25392
# WARNING:tensorflow:From /content/frustum-pointnets/models/model_util.py:175: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/frustum-pointnets/models/tf_util.py:155: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/frustum-pointnets/models/tf_util.py:21: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# ...

# %% [markdown]
# Visulization

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir /content/frustum-pointnets/train/log_v1

# %%
# !python kitti/kitti_object.py

# %%
# how to delete especial file in a directory in linux

# %% [markdown]
# BackUp

# %%
# !rm -r "/content/drive/MyDrive/Colab Notebooks/proposal_project/Frustum Pointnet/frustum-pointnets/train"
# !cp -R /content/frustum-pointnets/train "/content/drive/MyDrive/Colab Notebooks/proposal_project/Frustum Pointnet/frustum-pointnets"
